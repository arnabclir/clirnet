# %%
# !pip install dspy requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: dspy in /usr/local/lib/python3.12/dist-packages (3.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: backoff>=2.2 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.2.1)
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (1.5.2)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (1.109.1)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (2024.11.6)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.11.4)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (4.67.1)
# Requirement already satisfied: optuna>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (4.6.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.11.10)
# Requirement already satisfied: magicattr>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from dspy) (0.1.6)
# Requirement already satisfied: litellm>=1.64.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (1.80.0)
# Requirement already satisfied: diskcache>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (5.6.3)
# Requirement already satisfied: json-repair>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (0.54.1)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (8.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy) (4.11.0)
# Requirement already satisfied: asyncer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from dspy) (0.0.8)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (5.5.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.1.2)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (13.9.4)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (11.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.6.0)
# Requirement already satisfied: gepa==0.0.17 in /usr/local/lib/python3.12/dist-packages (from gepa[dspy]==0.0.17->dspy) (0.0.17)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy) (1.3.1)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (8.3.0)
# Requirement already satisfied: fastuuid>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.14.0)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (4.25.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.22.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (0.12.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (1.17.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (2.0.44)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy) (1.3.10)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy) (0.28.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->dspy) (0.1.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy) (3.2.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (1.2.0)

# %%
from typing import List
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

import dspy
from pydantic import BaseModel, Field

# %%
# Configure Longcat LLM with DSPy (OpenAI-compatible, Chat model)

LONGCAT_API_KEY = "ak_1Vo1sl9GT0sV3YM1df2AY9MU7KZ0u"

MODEL_NAME = "openai/LongCat-Flash-Chat"

lm = dspy.LM(
    model=MODEL_NAME,
    api_key=LONGCAT_API_KEY,
    api_base="https://api.longcat.chat/openai/v1",
)

dspy.configure(lm=lm)
print("LM configured:", MODEL_NAME)
# Out:
# LM configured: openai/LongCat-Flash-Chat

# %%
URLS = [
    "https://en.wikipedia.org/wiki/Sustainable_agriculture",
    "https://www.nature.com/articles/d41586-025-03353-5",
    "https://www.sciencedirect.com/science/article/pii/S1043661820315152",
    "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/",
    "https://www.fao.org/3/y4671e/y4671e06.htm",
    "https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria",
    "https://www.sciencedirect.com/science/article/pii/S0378378220307088",
    "https://www.frontiersin.org/news/2025/09/01/rectangle-telescope-finding-habitable-planets",
    "https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7",
    "https://www.theguardian.com/global-development/2025/oct/13/astro-ambassadors-stargazers-himalayas-hanle-ladakh-india",
]


def fetch_text(url: str) -> str:
    """Download page and extract main text. If blocked (403), return empty text."""
    print(f"Fetching: {url}")

    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/120.0 Safari/537.36"
        )
    }

    try:
        resp = requests.get(url, headers=headers, timeout=30)
        resp.raise_for_status()
    except requests.HTTPError as e:
        print(f"⚠️ HTTP error for {url}: {e}")
        print("   -> Skipping content extraction for this URL.")
        return ""
    except Exception as e:
        print(f"⚠️ Other error fetching {url}: {e}")
        print("   -> Skipping content extraction for this URL.")
        return ""

    soup = BeautifulSoup(resp.text, "html.parser")

    for tag in soup(["script", "style", "nav", "header", "footer", "aside"]):
        tag.decompose()

    text = soup.get_text(separator=" ")
    text = " ".join(text.split())
    return text


def chunk_text(text: str, max_chars: int = 1500) -> List[str]:
    """Split long text into smaller pieces for the model."""
    words = text.split()
    chunks = []
    current = []
    current_len = 0

    for w in words:
        current.append(w)
        current_len += len(w) + 1
        if current_len >= max_chars:
            chunks.append(" ".join(current))
            current = []
            current_len = 0

    if current:
        chunks.append(" ".join(current))

    print(f"Text split into {len(chunks)} chunks.")
    return chunks

# %%
class EntityWithAttr(BaseModel):
    entity: str = Field(description="exact entity phrase from the text")
    attr_type: str = Field(
        description=(
            "semantic type: Crop, Drug, Disease, Process, "
            "Measurement, Concept, Instrument, Organization, "
            "Location, Other"
        )
    )

class ExtractEntities(dspy.Signature):
    """
    You are a JSON API.

    INPUT: a paragraph of text.
    OUTPUT: ONLY valid JSON of the form:
    {
      "entities": [
        {"entity": "...", "attr_type": "..."},
        ...
      ]
    }

    Do NOT include explanations or thoughts outside the JSON.
    """
    paragraph: str = dspy.InputField()
    entities: List[EntityWithAttr] = dspy.OutputField()


class DeduplicateItems(dspy.Signature):
    """
    Input: list of entity strings.
    Output: deduplicated list + confidence score.
    """
    items: List[str] = dspy.InputField()
    deduplicated: List[str] = dspy.OutputField()
    confidence: float = dspy.OutputField(
        desc="0.0–1.0 confidence that deduplication is correct"
    )


class Triple(BaseModel):
    src: str = Field(description="source entity; must exactly match entities list")
    rel: str = Field(description="relationship label, max 40 chars")
    dst: str = Field(description="target entity; must exactly match entities list")


class ExtractTriples(dspy.Signature):
    """
    You are a JSON API.

    INPUT:
      - text: the full article text
      - entities: list of deduplicated entities
    OUTPUT: ONLY valid JSON of the form:
    {
      "triples": [
        {"src": "...", "rel": "...", "dst": "..."},
        ...
      ]
    }

    - src and dst MUST be copied exactly from the entities list.
    - rel must be a short phrase (<= 40 characters).
    - No extra explanation text.
    """
    text: str = dspy.InputField()
    entities: List[str] = dspy.InputField()
    triples: List[Triple] = dspy.OutputField()

# %%
class EntityExtractor(dspy.Module):
    def __init__(self):
        super().__init__()
        self.predict = dspy.Predict(ExtractEntities)

    def forward(self, paragraph: str) -> List[EntityWithAttr]:
        try:
            out = self.predict(paragraph=paragraph)
            return out.entities or []
        except Exception as e:
            print("⚠️ Entity extraction failed on a chunk:", e)
            return []


class DedupModule(dspy.Module):
    def __init__(self):
        super().__init__()
        self.predict = dspy.Predict(DeduplicateItems)

    def forward(self, items: List[str], target_confidence: float = 0.9) -> List[str]:
        if not items:
            return []

        try:
            pred = self.predict(items=items)
            conf = getattr(pred, "confidence", 0.0) or 0.0
            print(f"Dedup confidence from LLM: {conf}")
            candidates = pred.deduplicated or []
        except Exception as e:
            print("⚠️ Deduplication failed, falling back to raw items:", e)
            candidates = items

        # Simple Python dedup
        seen = set()
        result = []
        for c in candidates:
            key = c.strip().lower()
            if key and key not in seen:
                seen.add(key)
                result.append(c.strip())
        return result


class TripleExtractor(dspy.Module):
    def __init__(self):
        super().__init__()
        self.predict = dspy.Predict(ExtractTriples)

    def forward(self, text: str, entities: List[str]) -> List[Triple]:
        if not entities:
            return []
        try:
            out = self.predict(text=text, entities=entities)
            return out.triples or []
        except Exception as e:
            print("⚠️ Triple extraction failed on article:", e)
            return []


entity_extractor = EntityExtractor()
dedup_module = DedupModule()
triple_extractor = TripleExtractor()

print("Modules ready.")
# Out:
# Modules ready.

# %%
def _clean_node_label(s: str) -> str:
    s = s.strip()
    return s.replace('"', "'").replace("[", "").replace("]", "")


def triples_to_mermaid(triples: List[Triple], entity_list: List[str]) -> str:
    """
    Build a Mermaid graph where nodes are entities and edges are relationships.
    Only uses nodes from the deduplicated entity list.

    If no valid triples are available, fall back to a simple chain graph
    connecting the deduplicated entities with 'related_to' edges.
    """
    entity_set = {e.strip().lower() for e in entity_list}
    lines = ["```mermaid", "graph LR"]

    edges = []

    # 1) Use model-produced triples if possible
    for t in triples:
        src = t.src.strip()
        dst = t.dst.strip()
        rel = t.rel.strip()

        if src.lower() not in entity_set or dst.lower() not in entity_set:
            continue

        if len(rel) > 40:
            rel = rel[:37] + "..."

        src_label = _clean_node_label(src)
        dst_label = _clean_node_label(dst)

        edges.append((src_label, rel, dst_label))

    # 2) FALLBACK: if no edges but we have entities, create a simple chain
    if not edges and len(entity_list) >= 2:
        for i in range(len(entity_list) - 1):
            src_label = _clean_node_label(entity_list[i])
            dst_label = _clean_node_label(entity_list[i + 1])
            rel = "related_to"
            edges.append((src_label, rel, dst_label))

    # 3) Write edges to Mermaid
    for src_label, rel, dst_label in edges:
        lines.append(f'    "{src_label}" -- "{rel}" --> "{dst_label}"')

    lines.append("```")
    return "\n".join(lines)

# %%
def process_url(url: str):
    print("=" * 80)
    print(f"Processing: {url}")
    text = fetch_text(url)

    if not text:
        print("⚠️ No text fetched for this URL. Creating empty diagram.")
        dedup_with_types: List[tuple[str, str]] = []
        triples: List[Triple] = []
        mermaid_text = "```mermaid\ngraph LR\n```"
        return dedup_with_types, triples, mermaid_text

    chunks = chunk_text(text, max_chars=1500)

    all_entities: List[EntityWithAttr] = []

    for idx, ch in enumerate(chunks, start=1):
        print(f"  Extracting entities from chunk {idx}/{len(chunks)}...")
        ents = entity_extractor(paragraph=ch)
        all_entities.extend(ents)
        time.sleep(2)  # small pause to reduce rate-limits

    all_entity_strings = [e.entity for e in all_entities if e.entity.strip()]
    print(f"Total raw entities: {len(all_entity_strings)}")

    dedup_entities = dedup_module(all_entity_strings, target_confidence=0.9)
    print(f"Deduplicated entities: {len(dedup_entities)}")

    type_lookup = {}
    for e in all_entities:
        key = e.entity.strip().lower()
        if key not in type_lookup:
            type_lookup[key] = e.attr_type

    dedup_with_types = []
    for ent in dedup_entities:
        attr_type = type_lookup.get(ent.strip().lower(), "Concept")
        dedup_with_types.append((ent, attr_type))

    print("  Extracting triples...")
    triples = triple_extractor(text=text, entities=dedup_entities)
    print(f"Total triples: {len(triples)}")

    mermaid_text = triples_to_mermaid(triples, dedup_entities)

    return dedup_with_types, triples, mermaid_text

# %%
all_rows = []
seen_url_tag = set()

for i, url in enumerate(URLS, start=1):
    print(f"\n\nProcessing URL {i}: {url}")
    dedup_entities, triples, mermaid_text = process_url(url)

    # Save Mermaid diagram
    mermaid_filename = f"mermaid_{i}.md"
    with open(mermaid_filename, "w", encoding="utf-8") as f:
        f.write(mermaid_text)
    print(f"✅ Saved {mermaid_filename}")

    # Collect tags for CSV
    for ent, attr_type in dedup_entities:
        key = (url, ent.strip().lower())
        if key in seen_url_tag:
            continue
        seen_url_tag.add(key)
        all_rows.append({
            "link": url,
            "tag": ent,
            "tag_type": attr_type
        })

# Save tags.csv
df = pd.DataFrame(all_rows, columns=["link", "tag", "tag_type"])
df.to_csv("tags.csv", index=False)
print("\n All done. Saved tags.csv")

df.head()
# Out:
# Processing URL 1: https://en.wikipedia.org/wiki/Sustainable_agriculture
# ================================================================================
# Processing: https://en.wikipedia.org/wiki/Sustainable_agriculture
# Fetching: https://en.wikipedia.org/wiki/Sustainable_agriculture
# Text split into 93 chunks.
#   Extracting entities from chunk 1/93...
#   Extracting entities from chunk 2/93...
#   Extracting entities from chunk 3/93...
#   Extracting entities from chunk 4/93...
#   Extracting entities from chunk 5/93...
#   Extracting entities from chunk 6/93...
#   Extracting entities from chunk 7/93...
#   Extracting entities from chunk 8/93...
#   Extracting entities from chunk 9/93...
#   Extracting entities from chunk 10/93...
#   Extracting entities from chunk 11/93...
#   Extracting entities from chunk 12/93...
#   Extracting entities from chunk 13/93...
#   Extracting entities from chunk 14/93...
#   Extracting entities from chunk 15/93...
#   Extracting entities from chunk 16/93...
#   Extracting entities from chunk 17/93...
#   Extracting entities from chunk 18/93...
#   Extracting entities from chunk 19/93...
#   Extracting entities from chunk 20/93...
#   Extracting entities from chunk 21/93...
#   Extracting entities from chunk 22/93...
#   Extracting entities from chunk 23/93...
#   Extracting entities from chunk 24/93...
#   Extracting entities from chunk 25/93...
#   Extracting entities from chunk 26/93...
#   Extracting entities from chunk 27/93...
#   Extracting entities from chunk 28/93...
#   Extracting entities from chunk 29/93...
#   Extracting entities from chunk 30/93...
#   Extracting entities from chunk 31/93...
#   Extracting entities from chunk 32/93...
#   Extracting entities from chunk 33/93...
#   Extracting entities from chunk 34/93...
#   Extracting entities from chunk 35/93...
#   Extracting entities from chunk 36/93...
#   Extracting entities from chunk 37/93...
#   Extracting entities from chunk 38/93...
#   Extracting entities from chunk 39/93...
#   Extracting entities from chunk 40/93...
#   Extracting entities from chunk 41/93...
#   Extracting entities from chunk 42/93...
#   Extracting entities from chunk 43/93...
#   Extracting entities from chunk 44/93...
#   Extracting entities from chunk 45/93...
#   Extracting entities from chunk 46/93...
#   Extracting entities from chunk 47/93...
#   Extracting entities from chunk 48/93...
#   Extracting entities from chunk 49/93...
#   Extracting entities from chunk 50/93...
#   Extracting entities from chunk 51/93...
#   Extracting entities from chunk 52/93...
#   Extracting entities from chunk 53/93...
#   Extracting entities from chunk 54/93...
#   Extracting entities from chunk 55/93...
#   Extracting entities from chunk 56/93...
#   Extracting entities from chunk 57/93...
#   Extracting entities from chunk 58/93...
#   Extracting entities from chunk 59/93...
#   Extracting entities from chunk 60/93...
#   Extracting entities from chunk 61/93...
#   Extracting entities from chunk 62/93...
#   Extracting entities from chunk 63/93...
#   Extracting entities from chunk 64/93...
#   Extracting entities from chunk 65/93...
#   Extracting entities from chunk 66/93...
#   Extracting entities from chunk 67/93...
#   Extracting entities from chunk 68/93...
#   Extracting entities from chunk 69/93...
#   Extracting entities from chunk 70/93...
#   Extracting entities from chunk 71/93...
#   Extracting entities from chunk 72/93...
#   Extracting entities from chunk 73/93...
#   Extracting entities from chunk 74/93...
#   Extracting entities from chunk 75/93...
#   Extracting entities from chunk 76/93...
#   Extracting entities from chunk 77/93...
#   Extracting entities from chunk 78/93...
#   Extracting entities from chunk 79/93...
#   Extracting entities from chunk 80/93...
#   Extracting entities from chunk 81/93...
#   Extracting entities from chunk 82/93...
#   Extracting entities from chunk 83/93...
#   Extracting entities from chunk 84/93...
#   Extracting entities from chunk 85/93...
#   Extracting entities from chunk 86/93...
#   Extracting entities from chunk 87/93...
#   Extracting entities from chunk 88/93...
#   Extracting entities from chunk 89/93...
#   Extracting entities from chunk 90/93...
#   Extracting entities from chunk 91/93...
#   Extracting entities from chunk 92/93...
#   Extracting entities from chunk 93/93...
# Total raw entities: 2942
# ⚠️ Deduplication failed, falling back to raw items: Adapter JSONAdapter failed to parse the LM response.
#
# LM Response: {
#   "deduplicated": [
#     "Sustainable agriculture",
#     "Wikipedia",
#     "shade-grown coffee",
#     "polyculture",
#     "natural ecosystems",
#     "Trees",
#     "coffee plants",
#     "farmers",
#     "coffee",
#     "timber",
#     "ecosystem services",
#     "flexible business processes",
#     "farming practices",
#     "Agriculture",
#     "environmental footprint",
#     "climate change",
#     "food systems",
#     "anthropogenic greenhouse gas emissions",
#     "scarcity",
#     "water pollution",
#     "land degradation",
#     "deforestation",
#     "environment friendly methods of farming",
#     "crops",
#     "livestock",
#     "soil",
#     "water",
#     "biodiversity",
#     "permaculture",
#     "agroforestry",
#     "mixed farming",
#     "multiple cropping",
#     "crop rotation",
#     "Land sparing",
#     "conventional intensive agriculture",
#     "natural habitats",
#     "sustainable food systems",
#     "dietary shifts",
#     "sustainable diets",
#     "organic certification",
#     "Rainforest Alliance",
#     "Fair Trade",
#     "UTZ Certified",
#     "GlobalGAP",
#     "Bird Friendly",
#     "Common Code for the Coffee Community (4C)",
#     "West Asia",
#     "Ancient Egypt",
#     "Ancient Greece",
#     "Ancient Rome",
#     "Austronesia",
#     "Agricultural science",
#     "Agricultural History Review",
#     "Arab Agricultural Revolution",
#     "Argentina",
#     "Canada",
#     "China",
#     "Chile",
#     "Columbian exchange",
#     "Green Revolution",
#     "Indian subcontinent",
#     "Mesoamerica",
#     "Middle Ages",
#     "Neolithic Revolution",
#     "Organic farming",
#     "Palestine",
#     "Peru",
#     "United Kingdom",
#     "British Agricultural Revolution",
#     "Cheshire",
#     "Scotland",
#     "United States",
#     "African-American",
#     "California",
#     "Agrivoltaic",
#     "Animal husbandry",
#     "cattle",
#     "pigs",
#     "poultry",
#     "sheep",
#     "Dairy",
#     "Dryland",
#     "Extensive",
#     "Fertilizer",
#     "Free-range",
#     "Grazing",
#     "Convertible husbandry",
#     "Rotational grazing",
#     "Hobby",
#     "Intensive",
#     "Natural",
#     "Monoculture",
#     "Orchard",
#     "Organic",
#     "Paddy field",
#     "Ranching",
#     "Sharecropping",
#     "Sowing",
#     "Colonia",
#     "Slash-and-burn",
#     "Smallholding",
#     "Terrace",
#     "Steam sterilization",
#     "Hydroculture",
#     "Aquaculture",
#     "Aquaponics",
#     "Hydroponics",
#     "Aeroponics",
#     "Agribusiness",
#     "Agricultural cooperative",
#     "Agricultural supplies",
#     "Agricultural engineering",
#     "Agricultural technology",
#     "Precision",
#     "Biotechnology",
#     "Agronomy",
#     "Animal-free agriculture",
#     "Cash crop",
#     "Cellular agriculture",
#     "Cultural methods",
#     "Contract farming",
#     "Extensive farming",
#     "Farm",
#     "Farmhouse",
#     "Feed ratio",
#     "Horticulture",
#     "Intensive farming",
#     "Mechanised agriculture",
#     "Paludiculture",
#     "Plantation Polyculture",
#     "Rice-duck farming",
#     "Rice-fish system",
#     "Sustainable food system",
#     "Universities and colleges",
#     "Urban agriculture",
#     "Agriculturist profession",
#     "Agricultural machinery",
#     "Food origins",
#     "Government ministries",
#     "Cannabis cultivation",
#     "History of agriculture",
#     "Meat industry",
#     "Poultry farming",
#     "Agriculture and the environment",
#     "Agriculture portal",
#     "USDA",
#     "indigenous communities",
#     "sustainable farming",
#     "growing populations",
#     "sustainability field",
#     "farm productivity",
#     "planet's carrying capacity",
#     "planetary boundaries",
#     "nutrient cycling",
#     "soil regeneration",
#     "nitrogen fixation",
#     "non-renewable and unsustainable inputs",
#     "expertise of farmers",
#     "self-reliance",
#     "self-sufficiency",
#     "cooperation and collaboration",
#     "pest management",
#     "irrigation",
#     "long-term economics",
#     "short-term economics",
#     "agricultural environments",
#     "endless regeneration",
#     "resource conservation",
#     "reconciliation ecology",
#     "sustainable practices",
#     "farming",
#     "technology",
#     "environmentally-focused appropriate technology",
#     "sustainable agricultural systems",
#     "AI research and development",
#     "resource optimization",
#     "crop health monitoring",
#     "yield prediction",
#     "AI-controlled irrigation systems",
#     "sensors",
#     "soil moisture levels",
#     "weather conditions",
#     "water management technology",
#     "water consumption",
#     "Artificial intelligence (AI) mobile soil analysis",
#     "soil fertility",
#     "ecological footprint",
#     "soil nutrient levels",
#     "Intelligent systems",
#     "weeds",
#     "pests",
#     "plant disease",
#     "farming productivity",
#     "2023 review article",
#     "agroecology",
#     "ecological practices of farming",
#     "regional and global scales",
#     "economic viability",
#     "ecological methods",
#     "digitalization",
#     "precision breeding",
#     "Agrivoltaics",
#     "solar panels",
#     "clean energy",
#     "land use",
#     "microclimates",
#     "eco-friendly farming practices",
#     "tilling",
#     "erosion",
#     "drainage",
#     "salinization",
#     "Conservation farming",
#     "Zambia",
#     "climate",
#     "nutrients",
#     "water resources",
#     "water and soil conservation",
#     "nutrient depletion",
#     "reduced yields",
#     "non-renewable resources",
#     "natural gas",
#     "mineral ores",
#     "environmental quality",
#     "global view",
#     "manure",
#     "productivity",
#     "rivers",
#     "coastal waters",
#     "eutrophication",
#     "crop yields",
#     "rainforest destruction",
#     "Asia",
#     "12.5 acres",
#     "5.1 ha",
#     "animal fodder",
#     "cereal production",
#     "food crops",
#     "AARI-1996",
#     "Nitrates",
#     "leaching",
#     "crop waste",
#     "treated human manure",
#     "legume crops",
#     "forages",
#     "peanuts",
#     "alfalfa",
#     "nitrogen-fixing bacteria",
#     "rhizobia",
#     "industrial production",
#     "nitrogen",
#     "Haber process",
#     "hydrogen",
#     "electrolysis",
#     "renewable electricity",
#     "genetically engineering",
#     "non-legume crops",
#     "microbial symbionts",
#     "1970s",
#     "flooding of the Nile",
#     "biochar",
#     "crop and livestock landraces",
#     "drought",
#     "lack of nutrients",
#     "fertilizer management practices",
#     "Phosphate",
#     "Phosphorus fertilizers",
#     "phosphate-containing chemical fertilizers",
#     "soil microbial life",
#     "rock phosphate",
#     "mining",
#     "agricultural use",
#     "peak phosphorus",
#     "Potassium",
#     "macronutrient",
#     "plant development",
#     "fertilizers",
#     "water retention",
#     "nutrient value",
#     "yield",
#     "taste",
#     "color",
#     "texture",
#     "disease resistance",
#     "grains",
#     "fruits",
#     "vegetables",
#     "rice",
#     "wheat",
#     "millets",
#     "sugar",
#     "corn",
#     "soybeans",
#     "palm oil",
#     "Potassium chloride",
#     "KCl",
#     "chloride",
#     "soil salinity",
#     "nutrient availability",
#     "biocidal effect",
#     "soil organisms",
#     "soil biodiversity",
#     "agricultural productivity",
#     "chloride-free fertilizers",
#     "plants' nutrition needs",
#     "soil health",
#     "Walls built to avoid water run-off",
#     "Andhra Pradesh",
#     "India",
#     "Intergovernmental Panel on Climate Change",
#     "Earth's ice-free land area",
#     "human-induced degradation",
#     "Soil erosion",
#     "agricultural fields",
#     "no tillage",
#     "conventional tillage",
#     "soil formation rate",
#     "dry land",
#     "southern Africa",
#     "wheat farms",
#     "conventional methods",
#     "soil quality",
#     "organic matter",
#     "microbial populations",
#     "nutrient content",
#     "net returns",
#     "input costs",
#     "Improper soil management",
#     "food",
#     "Intensive agriculture",
#     "carbon level in soil",
#     "soil structure",
#     "crop growth",
#     "ecosystem functioning",
#     "carbon sequestration",
#     "carbon sink",
#     "soil management techniques",
#     "no-till farming",
#     "keyline design",
#     "windbreaks",
#     "wind erosion",
#     "soil salinization",
#     "water run-off",
#     "land-use planning",
#     "land-use changes",
#     "Wadi Ziqlab",
#     "Middle East",
#     "olives",
#     "vegetables",
#     "grains",
#     "developing countries",
#     "rural poverty",
#     "smallholder farmers",
#     "unsustainable agricultural practices",
#     "environmental consequences",
#     "health consequences",
#     "zoonotic disease",
#     "Coronavirus disease 2019",
#     "natural buffers",
#     "animals",
#     "genetically similar animals",
#     "Land",
#     "Earth",
#     "agricultural land",
#     "sheep",
#     "Norse settlers",
#     "Vikings",
#     "Faroe Islands",
#     "North Atlantic",
#     "Food and Agriculture Organization of the United Nations",
#     "cropland",
#     "industrial development",
#     "urban development",
#     "wetlands",
#     "forest",
#     "cultivation",
#     "energy",
#     "modern agriculture",
#     "on-farm mechanisation",
#     "food processing",
#     "storage",
#     "transportation processes",
#     "energy prices",
#     "food prices",
#     "Oil",
#     "agricultural chemicals",
#     "International Energy Agency",
#     "non-renewable energy resources",
#     "fossil fuel resources",
#     "global food security",
#     "fossil fuel energy",
#     "food production",
#     "renewable energy",
#     "solar powered irrigation",
#     "Pakistan",
#     "agricultural water irrigation",
#     "environmental cost of transportation",
#     "local products",
#     "rainfall",
#     "crop growth",
#     "water source",
#     "water well drilling technology",
#     "submersible pumps",
#     "drip irrigation",
#     "low-pressure pivots",
#     "Ogallala Aquifer",
#     "UC Davis Agricultural Sustainability Institute",
#     "drought-resistant farming systems",
#     "water conservation",
#     "water storage",
#     "drought-tolerant crop species",
#     "reduced-volume irrigation systems",
#     "water loss",
#     "planting crops",
#     "sustainable water resource development",
#     "average annual flow of rivers",
#     "flows from outside a country",
#     "percentage of water coming from outside a country",
#     "gross water withdrawal",
#     "69% of the world's fresh water",
#     "wool",
#     "Wyoming",
#     "environmental degradation",
#     "crop",
#     "food output",
#     "rural economic development",
#     "small-scale farming communities",
#     "unrestricted markets",
#     "food a human right",
#     "rural poverty reduction",
#     "sustainable economic growth",
#     "poorest farmers",
#     "economy-wide development",
#     "stabilization of small-scale agricultural economies",
#     "United Nations",
#     "Organic Agriculture and Food Security in Africa",
#     "global food security",
#     "land usage",
#     "environmental impacts",
#     "developing nations",
#     "Charles Kellogg",
#     "exploited people",
#     "agricultural process",
#     "Uganda",
#     "Genetically Modified Organisms",
#     "banana crisis",
#     "Banana Bacterial Wilt",
#     "National Biotechnology and Biosafety bill",
#     "National Banana Research Program",
#     "scientists",
#     "local communities",
#     "food they grow themselves",
#     "Nepal",
#     "greenhouses",
#     "crop production",
#     "Desalination techniques",
#     "salt water",
#     "fresh water",
#     "desalination",
#     "money",
#     "resources",
#     "Regions of China",
#     "Women",
#     "academia",
#     "labour",
#     "women farm operators",
#     "conventional agriculture",
#     "Growing your own food",
#     "Urban agriculture",
#     "US",
#     "World War I",
#     "Great Depression",
#     "World War II",
#     "40%",
#     "vegetables",
#     "USA",
#     "COVID-19 pandemic",
#     "food",
#     "poor people",
#     "Economic factors",
#     "environmental problems",
#     "traditional accounting systems",
#     "externalities",
#     "Netting",
#     "sustainability",
#     "smallholder systems",
#     "land degradation",
#     "sustainable land management",
#     "The Economics of Ecosystems and Biodiversity study",
#     "Economics of Land Degradation Initiative",
#     "economic cost-benefit analysis",
#     "Triple bottom line frameworks",
#     "social",
#     "environmental",
#     "financial bottom line",
#     "sustainable future",
#     "material consumption",
#     "population",
#     "efficiency",
#     "material",
#     "energy use",
#     "hunger",
#     "direct food assistance",
#     "humanitarian funds",
#     "social pillar",
#     "environmental pillar",
#     "economic pillar",
#     "economic growth",
#     "livelihoods",
#     "cultural shifts",
#     "collaboration",
#     "incentives",
#     "new legislation",
#     "behavioural changes",
#     "consumers",
#     "Cooperation",
#     "competition",
#     "profitability",
#     "public policy",
#     "advertisements",
#     "laws",
#     "Pesticide use",
#     "Environmental barriers",
#     "pesticides",
#     "green pesticides",
#     "human health",
#     "habitats",
#     "production cost",
#     "topography",
#     "production",
#     "conventional practices",
#     "soil structure",
#     "beneficial microorganisms",
#     "surrounding ecosystems",
#     "biodiversity loss",
#     "disrupted ecosystems",
#     "poor water quality",
#     "sustainable agricultural practices",
#     "financial return/profitability",
#     "financial incentives",
#     "capital investments",
#     "human and material capital",
#     "training of the workforce",
#     "new technology",
#     "new products",
#     "high cost",
#     "mass-produce",
#     "Community gardening",
#     "James Howard Kunstler",
#     "modern technology",
#     "ancient traditional ways",
#     "sustainability community",
#     "incremental steps",
#     "local farming",
#     "community gardens",
#     "local produce",
#     "agricultural education",
#     "schools",
#     "communities",
#     "institutions",
#     "freshly grown produce",
#     "consumer demand",
#     "sustainable steady state economy",
#     "reduced energy usage",
#     "minimal ecological footprint",
#     "consumer packaged goods",
#     "local purchasing",
#     "short food supply chains",
#     "processed foods",
#     "home and community gardens",
#     "definition of sustainability",
#     "ecocentric approach",
#     "technocentric approach",
#     "organic and biodynamic farming techniques",
#     "consumption patterns",
#     "resource allocation and usage",
#     "state-led modification of the industrial system",
#     "conservation-oriented farming systems",
#     "multifunctional agriculture",
#     "farm-centered approaches",
#     "agricultural activity",
#     "renewable resource management",
#     "landscape conservation",
#     "ecosystem service-centered approach",
#     "ecosystems",
#     "pollination",
#     "soil formation",
#     "Nitrogen fixation",
#     "legumes",
#     "nitrate",
#     "ammonium",
#     "weed management",
#     "herbicide-resistant weeds",
#     "Crop rotation",
#     "rotational grazing",
#     "pasture",
#     "paddocks",
#     "sustainable animal husbandry",
#     "grazing management",
#     "fencing",
#     "stock density",
#     "integrated wheat-fish farming",
#     "Egypt",
#     "rice-fish culture",
#     "farming activities",
#     "intensification",
#     "intensive farming",
#     "sustainable intensification",
#     "environmental outcomes",
#     "land cultivation",
#     "natural habitat",
#     "Sustainable intensification",
#     "2018",
#     "100 nations",
#     "163 million farms",
#     "453 million ha of land",
#     "29% of farms worldwide",
#     "food security",
#     "human population growth",
#     "sustainable intensive farming practises",
#     "irrigated rice production system",
#     "east Asia",
#     "biological control",
#     "nectar plants",
#     "insecticides",
#     "70%",
#     "5% yield advantage",
#     "Vertical farming",
#     "year-round production",
#     "resource recycling",
#     "transportation costs",
#     "Water efficiency",
#     "drought resistant crops",
#     "plant transpiration",
#     "soil evaporation",
#     "water shortage",
#     "compost",
#     "recycling centers",
#     "yard and kitchen waste",
#     "soil tillage",
#     "plant residue",
#     "crop residues",
#     "surface soil temperature",
#     "wind effects",
#     "microbial inoculates",
#     "phosphate-solubilizing microorganisms",
#     "PSMs",
#     "phosphorus",
#     "organic acid production",
#     "ion exchange reactions",
#     "shoot height",
#     "dry biomass",
#     "grain yield",
#     "Phosphorus uptake",
#     "mycorrhizae",
#     "mutualistic symbiotic association",
#     "fungi",
#     "aluminum",
#     "calcium",
#     "iron",
#     "organic acids",
#     "Sheet steaming",
#     "MSD/moeschle steam boiler",
#     "Soil steaming",
#     "chemicals",
#     "soil sterilization",
#     "steam",
#     "Solarizing",
#     "temperature",
#     "pathogens",
#     "biofumigants",
#     "natural fumigants",
#     "Brassicaceae family",
#     "methyl isothiocyanates",
#     "croplands",
#     "crop production",
#     "carbon footprint",
#     "biodiversity footprint",
#     "irrigation water footprint",
#     "cover crops",
#     "topsoil",
#     "pest pressure",
#     "weed control",
#     "disease build up",
#     "nutrient cycling",
#     "pesticides",
#     "genetic resources",
#     "Perennial crops",
#     "water quality",
#     "soil organic matter",
#     "Thinopyrum intermedium",
#     "hybrids",
#     "Landscape management strategies",
#     "land sparing",
#     "land sharing",
#     "land blending",
#     "biodiversity conservation",
#     "agricultural production",
#     "rural livelihoods",
#     "tropical forest biodiversity",
#     "landscape scale",
#     "nature elements",
#     "conservation of natural habitats",
#     "yield",
#     "biodiversity",
#     "developed countries",
#     "wildlife-friendly agriculture",
#     "agroecological practices",
#     "mixed crop-livestock systems",
#     "resilience",
#     "Organic agriculture",
#     "Organic Farming",
#     "sustainability",
#     "soil fertility",
#     "biological diversity",
#     "synthetic pesticides",
#     "antibiotics",
#     "synthetic fertilizers",
#     "genetically modified organisms",
#     "growth hormones",
#     "organic products",
#     "$52.5 billion",
#     "Americans",
#     "carbon dioxide emissions",
#     "land-use change",
#     "forestry",
#     "3–4 GtCO2 per year",
#     "anthropogenic CO2 emissions",
#     "Ecological farming",
#     "environmental aspects",
#     "water infiltration",
#     "water retention",
#     "humus",
#     "increased biodiversity",
#     "multispecies cover crops",
#     "strip cropping",
#     "terrace cultivation",
#     "shelter belts",
#     "pasture cropping",
#     "Crop genetic diversity",
#     "monoculture crops",
#     "changing climate",
#     "biodigestors",
#     "organic waste",
#     "combustible gas",
#     "fuel source",
#     "fish ponds",
#     "industrial fertilizers",
#     "aquaculture integration",
#     "fish farming",
#     "agricultural farming",
#     "wastes from animals and crops",
#     "fish farms",
#     "Mud from the fish ponds",
#     "organic fertilizers",
#     "animal manure",
#     "green manure",
#     "Precision Agriculture",
#     "Nitrogen",
#     "Phosphorus",
#     "false seedbed tiller",
#     "small weeds",
#     "soil disturbance",
#     "contour farming",
#     "Ecological farming",
#     "symbiotic species",
#     "ecological sustainability",
#     "ecological debt",
#     "dead zones",
#     "specialized automata",
#     "soil and plant situations",
#     "intensive care",
#     "conversion",
#     "information age",
#     "robotics",
#     "expert systems",
#     "mainstream productive food system",
#     "sustainable",
#     "regenerative",
#     "location",
#     "consumer",
#     "food miles",
#     "biosphere",
#     "combustion engine emissions",
#     "food transportation",
#     "ecological farm",
#     "local climate",
#     "soil's physical properties",
#     "budget",
#     "beneficial soil supplements",
#     "manpower",
#     "automatons",
#     "long-term water management",
#     "water availability",
#     "fertility",
#     "origin",
#     "destiny",
#     "post-harvest ecological footprint",
#     "alternative products",
#     "packaging",
#     "energy consumption",
#     "waste",
#     "new ecosystem",
#     "human needs",
#     "existing ecosystems",
#     "soil microorganisms",
#     "Forest Gardens",
#     "denitrifiers",
#     "Traditional agriculture",
#     "slash-and-burn",
#     "slash-and-char shifting cultivation",
#     "Amazon",
#     "rice-fish systems",
#     "rice paddies",
#     "freshwater fish",
#     "eutrophication",
#     "Indonesia",
#     "rice, fish, ducks and water fern",
#     "herbicides",
#     "duck and fish manure",
#     "raised field agriculture",
#     "Altiplano region",
#     "Bolivia",
#     "Waru Waru raised fields",
#     "nutrient-rich soil",
#     "indigenous groups",
#     "Amazon Basin",
#     "agro forestry",
#     "water harvesting",
#     "Ethiopia",
#     "GDP",
#     "exports",
#     "droughts",
#     "dry periods",
#     "Rain water harvesting",
#     "roof tops",
#     "high-rain periods",
#     "runoff irrigation",
#     "roof water harvesting",
#     "flood spreading",
#     "Indigenous Agriculture",
#     "North America",
#     "Native Americans",
#     "subsistence farming techniques",
#     "local environment",
#     "local biodiversity",
#     "Intercropping",
#     "Three Sisters Garden",
#     "corn",
#     "beans",
#     "squash",
#     "weed growth",
#     "crop yield",
#     "indigenous sustainable agriculture",
#     "traditional ecological knowledge",
#     "Anishinaabe tribes",
#     "the Honorable Harvest",
#     "agroforestry",
#     "forest",
#     "controlled burns",
#     "silviculture",
#     "ash",
#     "Regenerative agriculture",
#     "topsoil regeneration",
#     "water cycle",
#     "biosequestration",
#     "farm waste",
#     "composted material",
#     "land management",
#     "settlement design",
#     "whole-systems thinking",
#     "town planning",
#     "rewilding",
#     "community resilience",
#     "Bill Mollison",
#     "David Holmgren",
#     "modern industrialized methods",
#     "traditional approach",
#     "natural approach",
#     "no-dig gardening",
#     "permanent agriculture",
#     "Permaculture One",
#     "Permaculture Design Course",
#     "Southern Australia",
#     "appropriate technology",
#     "intentional community design",
#     "foundational ethics",
#     "twelve design principles",
#     "companion planting",
#     "herb spiral",
#     "soil quality",
#     "social movement",
#     "agroecological transition",
#     "meta-analysis",
#     "predator insect biodiversity",
#     "two-crop systems",
#     "cover crop",
#     "perennial crop varieties",
#     "sorghum",
#     "barley",
#     "sunflowers",
#     "leguminous cover crop",
#     "local small-scale agriculture",
#     "city space",
#     "rooftop gardens",
#     "garden sharing",
#     "organopónicos",
#     "guerrilla gardening",
#     "seeds of edible plants",
#     "local rural areas",
#     "soil-less culture",
#     "farming technique",
#     "cost",
#     "Certification systems",
#     "agriculture community",
#     "consumers",
#     "sustainability of produce",
#     "producers",
#     "manufacturers",
#     "traders",
#     "Voluntary Sustainability Standards (VSS)",
#     "economic sustainability metrics",
#     "social sustainability metrics",
#     "environmental sustainability metrics",
#     "product quality",
#     "production and processing methods",
#     "transportation",
#     "non-governmental organizations (NGOs)",
#     "private firms",
#     "retailers",
#     "Certifications",
#     "labels",
#     "ITC standards map",
#     "agricultural products",
#     "tea",
#     "bananas",
#     "cocoa",
#     "cotton",
#     "organic agri-foods",
#     "natural ecosystem conversion",
#     "organic label",
#     "organic system plan",
#     "produce",
#     "tilled",
#     "grazed",
#     "harvested",
#     "stored",
#     "transported",
#     "USDA certifying agent",
#     "approval sticker",
#     "U.S.",
#     "Delaware Valley University",
#     "Roth Center for Sustainable Agriculture",
#     "Montgomery County",
#     "Pennsylvania",
#     "Commission on Sustainable Agriculture and Climate Change",
#     "agricultural yields",
#     "resilience",
#     "land rehabilitation",
#     "economic incentives",
#     "infrastructure improvement",
#     "2021 United Nations Climate Change Conference",
#     "45 countries",
#     "Slow Food",
#     "technological solutions",
#     "reforestation",
#     "holistic agroecology",
#     "CO 2 emissions",
#     "carbon neutral",
#     "coal",
#     "methane emissions",
#     "Climate Action Tracker",
#     "2.7 °C temperature increase",
#     "coal and natural gas consumption",
#     "Africa",
#     "developing countries",
#     "wealthy nations",
#     "European Union",
#     "European Green Deal",
#     "From Farm to Fork",
#     "Frans Timmermans",
#     "European Commission",
#     "coronavirus crisis",
#     "health and well-being",
#     "EU",
#     "nutrient loss",
#     "antimicrobials",
#     "sustainable food labeling",
#     "food waste",
#     "R&I",
#     "The New Deal",
#     "Agriculture Adjustment Act of 1933",
#     "supply management regime",
#     "Cooperative Extension Service",
#     "land-grant universities",
#     "Agricultural Act of 1954",
#     "Food and Agricultural Act of 1965",
#     "Agriculture and Consumer Protection Act of 1973",
#     "Food Security Act of 1985",
#     "commodity crops",
#     "cotton",
#     "Natural Resources Conservation Service",
#     "SARE",
#     "China-UK SAIN",
#     "target prices",
#     "deficiency payments",
#     "commodity loan programs",
#     "price supports",
#     "income support payments",
#     "supply controls",
#     "New Deal",
#     "decentralizing agrarian governance",
#     "large commodity farms",
#     "1950s to 1980s",
#     "climate change mitigation",
#     "landscape-scale ecological stewardship",
#     "Green New Deal",
#     "public infrastructure",
#     "industrial food regime",
#     "agroecological skills",
#     "cooperatives and commons",
#     "equipment, research facilities, personnel, and training programs",
#     "sustainable farmers",
#     "Asia",
#     "2016",
#     "Chinese government",
#     "meat consumption",
#     "50%",
#     "sustainable and healthy food system",
#     "2019",
#     "National Basic Research Program",
#     "Program 973",
#     "Science and Technology Backyard",
#     "STBs",
#     "rural areas",
#     "small-scale farming",
#     "traditional practices",
#     "new innovations",
#     "technology implementation",
#     "negative environmental effects",
#     "appropriate technology",
#     "Food and Land Use Coalition",
#     "FOLU",
#     "CEEW",
#     "council for energy, environment and water",
#     "sustainable agriculture practices and systems",
#     "SAPSs",
#     "policymakers",
#     "administrators",
#     "philanthropists",
#     "conventional, input-intensive agriculture",
#     "16 SAPSs",
#     "rainwater harvesting",
#     "natural farming",
#     "restructured government support",
#     "rigorous evidence generation",
#     "Indian Agriculture",
#     "Sowgood foundation",
#     "nonprofit",
#     "Pragati Chaswal",
#     "primary school children",
#     "Delhi, India",
#     "sowgood foundation curriculum",
#     "government and private schools",
#     "Israeli Ministry of Agriculture",
#     "sustainable agriculture policy",
#     "Palestinian-Arab communities",
#     "sustainable agriculture methods",
#     "agriculture stakeholders",
#     "Franklin H. King",
#     "Farmers of Forty Centuries",
#     "Gordon McClymont",
#     "Australian agronomist",
#     "International Society of Horticultural Science",
#     "International Horticultural Congress",
#     "Toronto",
#     "Seoul",
#     "sustainability in horticulture",
#     "Thomas Malthus",
#     "English political economist",
#     "early 1800s",
#     "twentieth century",
#     "twenty-first century",
#     "global population",
#     "land",
#     "water",
#     "labor",
#     "population growth",
#     "global food insecurity",
#     "solving hunger",
#     "Agronomy",
#     "Ecology",
#     "Agroecology",
#     "Climate-smart agriculture",
#     "Environmental impact of meat production",
#     "Sustainable development",
#     "Sustainable energy",
#     "Sustainable landscaping",
#     "Agricultural Sustainability Institute",
#     "Ontario Ministry of Agriculture, Food and Rural Affairs",
#     "FAO",
#     "Nature Food",
#     "Brown, L. R.",
#     "World on the Edge",
#     "Earth Policy Institute",
#     "Rockström, Johan",
#     "Williams, John",
#     "Daily, Gretchen",
#     "Noble, Andrew",
#     "Matthews, Nathanial",
#     "Gordon, Line",
#     "Wetterstrand, Hanna",
#     "DeClerck, Fabrice",
#     "Shah, Mihir",
#     "Ambio",
#     "Falk, Ben",
#     "The Resilient Farm and Homestead",
#     "Chelsea Green",
#     "Green, Rhys E.",
#     "Cornell, Stephen J.",
#     "Scharlemann, Jörn P. W.",
#     "Balmford, Andrew",
#     "Science",
#     "Rose, Donald",
#     "Heller, Martin C.",
#     "Roberto, Christina A.",
#     "Journal of Nutrition Education and Behavior",
#     "Society for Nutrition Education and Behavior",
#     "Sustainable intensification of agriculture",
#     "Farming and the Fate of Wild Nature",
#     "Shifting to Sustainable Diets",
#     "environmental sustainability",
#     "dietary guidance",
#     "global anthropogenic GHG emissions",
#     "whole systems design",
#     "wild nature",
#     "human prosperity",
#     "global sustainability",
#     "Meybeck, Alexandre",
#     "Gitz, Vincent",
#     "Proceedings of the Nutrition Society",
#     "Sun, Zhongxiao",
#     "Scherer, Laura",
#     "Tukker, Arnold",
#     "Spawn-Lee, Seth A.",
#     "Bruckner, Martin",
#     "Gibbs, Holly K.",
#     "Behrens, Paul",
#     "National Agricultural Research, Extension, and Teaching Policy Act of 1977",
#     "Pilgeram, Ryanne",
#     "Sociology Compass",
#     "Ehrlich, Paul R.",
#     "Ehrlich, Anne H.",
#     "Daily, Gretchen C.",
#     "Population and Development Review",
#     "Singh, R.",
#     "Upadhyay, S.",
#     "Srivastava, P.",
#     "Raghubanshi, A. S.",
#     "Pretty, Jules N.",
#     "Low-input, sustainable agriculture",
#     "Sustainable Agriculture Research and Education Program",
#     "University of California",
#     "Davis, California",
#     "Farming Systems",
#     "AI in Agriculture",
#     "Efficient Irrigation",
#     "Pest Control",
#     "Artificial intelligence SoS framework",
#     "sustainable agricultural production",
#     "AI-Driven Future Farming",
#     "Climate-Smart",
#     "Plants, Genes, and Agriculture",
#     "Journal of Soil and Water Conservation",
#     "Computers and Electronics in Agriculture",
#     "MDPI Journals",
#     "Agriculture and Food System",
#     "Annual Review of Resource Economics",
#     "Yale Center for Business and the Environment",
#     "Liu, Zhanjun",
#     "Chen, Zhujun",
#     "Ma, Pengyi",
#     "Meng, Yan",
#     "Zhou, Jianbin",
#     "mulching",
#     "N management",
#     "water productivity",
#     "N uptake",
#     "residual soil nitrate",
#     "wheat-summer maize cropping system",
#     "Field Crops Research",
#     "Singh, Ajay",
#     "Salinization",
#     "drainage problems",
#     "Irrigation and Drainage",
#     "Xia, Yinfeng",
#     "Zhang, Ming",
#     "Tsang, Daniel C. W.",
#     "Geng, Nan",
#     "Lu, Debao",
#     "Zhu, Lifang",
#     "Igalavithana, Avanthi Deshani",
#     "Dissanayake, Pavani Dulanja",
#     "Rinklebe, Jörg",
#     "Yang, Xiao",
#     "Ok, Yong Sik",
#     "non-point source pollution",
#     "phosphorous",
#     "agricultural runoff",
#     "Applied Biological Chemistry",
#     "rainforests",
#     "Rainforest Concern",
#     "Current Science",
#     "Recycling of livestock manure",
#     "whole-farm perspective",
#     "Livestock Science",
#     "Nitrogen Fixing Plants and Microbiome Research",
#     "Plants",
#     "non-leguminous crops",
#     "BMC Biology",
#     "genetics of nitrogen fixation",
#     "future agriculture",
#     "News.mongabay.com",
#     "SymRK",
#     "arbuscular mycorrhiza fungi",
#     "Frankia bacteria",
#     "Proceedings of the National Academy of Sciences",
#     "phosphate solubilizing bacteria",
#     "sugarcane wastes",
#     "Journal of Degraded and Mining Lands Management",
#     "phosphate-solubilizing microorganisms",
#     "Agronomy for Sustainable Development",
#     "Cordell, Dana",
#     "White, Stuart",
#     "phosphate solubilizing microbes",
#     "SpringerPlus",
#     "Bhattacharya, Amitav",
#     "Environmental Condition",
#     "Phosphorus-Use Efficiency",
#     "Changing Climate",
#     "Resource Use Efficiency",
#     "Academic Press",
#     "Green, B.W.",
#     "Fertilizers in aquaculture",
#     "Feed and Feeding Practices in Aquaculture",
#     "Woodhead Publishing",
#     "IFDC.org",
#     "IFDC Report",
#     "Phosphorus Resources",
#     "Jasinski, SM",
#     "Mineral Commodity Summaries",
#     "U.S. Geological Survey",
#     "Van Kauwenbergh, Steven J.",
#     "World Phosphate Rock Reserves and Resources",
#     "Muscle Shoals, AL, USA",
#     "International Fertilizer Development Center (IFDC)",
#     "Edixhoven, J.D.",
#     "Gupta, J.",
#     "Savenije, H.H.G.",
#     "Recent revisions of phosphate rock reserves and resources",
#     "Earth System Dynamics",
#     "The story of phosphorus",
#     "Global Environmental Change",
#     "Peak Phosphorus",
#     "crop production",
#     "Potash",
#     "bananeira 'Prata anã'",
#     "potássio",
#     "Revista Ceres",
#     "INFORMaÇÕES E aNáLISES Da ECONOMIa MINERaL BRaSILEIRa",
#     "Chloride ion",
#     "nitrification inhibitor",
#     "biocidal potential",
#     "Plant and Cell Physiology",
#     "toxicant",
#     "nutrient",
#     "soil microbial activity",
#     "nitrogen mineralization",
#     "Ciência Rural",
#     "salin
#
# Expected to find output fields in the LM response: [deduplicated, confidence]
#
# Actual output fields parsed from the LM response: [deduplicated]
#
#
# Deduplicated entities: 2316
#   Extracting triples...
# ⚠️ Triple extraction failed on article: litellm.InternalServerError: InternalServerError: OpenAIException - Connection error.
# Total triples: 0
# ✅ Saved mermaid_1.md
#
#
# Processing URL 2: https://www.nature.com/articles/d41586-025-03353-5
# ================================================================================
# Processing: https://www.nature.com/articles/d41586-025-03353-5
# Fetching: https://www.nature.com/articles/d41586-025-03353-5
# Text split into 3 chunks.
#   Extracting entities from chunk 1/3...
#   Extracting entities from chunk 2/3...
#   Extracting entities from chunk 3/3...
# Total raw entities: 56
# Dedup confidence from LLM: 0.92
# Deduplicated entities: 52
#   Extracting triples...
# Total triples: 30
# ✅ Saved mermaid_2.md
#
#
# Processing URL 3: https://www.sciencedirect.com/science/article/pii/S1043661820315152
# ================================================================================
# Processing: https://www.sciencedirect.com/science/article/pii/S1043661820315152
# Fetching: https://www.sciencedirect.com/science/article/pii/S1043661820315152
# ⚠️ HTTP error for https://www.sciencedirect.com/science/article/pii/S1043661820315152: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S1043661820315152
#    -> Skipping content extraction for this URL.
# ⚠️ No text fetched for this URL. Creating empty diagram.
# ✅ Saved mermaid_3.md
#
#
# Processing URL 4: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/
# ================================================================================
# Processing: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/
# Fetching: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/
# ⚠️ HTTP error for https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/: 403 Client Error: Forbidden for url: https://pmc.ncbi.nlm.nih.gov/articles/PMC10457221/
#    -> Skipping content extraction for this URL.
# ⚠️ No text fetched for this URL. Creating empty diagram.
# ✅ Saved mermaid_4.md
#
#
# Processing URL 5: https://www.fao.org/3/y4671e/y4671e06.htm
# ================================================================================
# Processing: https://www.fao.org/3/y4671e/y4671e06.htm
# Fetching: https://www.fao.org/3/y4671e/y4671e06.htm
# Text split into 15 chunks.
#   Extracting entities from chunk 1/15...
#   Extracting entities from chunk 2/15...
#   Extracting entities from chunk 3/15...
#   Extracting entities from chunk 4/15...
#   Extracting entities from chunk 5/15...
#   Extracting entities from chunk 6/15...
#   Extracting entities from chunk 7/15...
#   Extracting entities from chunk 8/15...
#   Extracting entities from chunk 9/15...
#   Extracting entities from chunk 10/15...
#   Extracting entities from chunk 11/15...
#   Extracting entities from chunk 12/15...
#   Extracting entities from chunk 13/15...
#   Extracting entities from chunk 14/15...
#   Extracting entities from chunk 15/15...
# Total raw entities: 306
# Dedup confidence from LLM: 0.98
# Deduplicated entities: 241
#   Extracting triples...
# Total triples: 95
# ✅ Saved mermaid_5.md
#
#
# Processing URL 6: https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria
# ================================================================================
# Processing: https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria
# Fetching: https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria
# ⚠️ HTTP error for https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria: 403 Client Error: Forbidden for url: https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria
#    -> Skipping content extraction for this URL.
# ⚠️ No text fetched for this URL. Creating empty diagram.
# ✅ Saved mermaid_6.md
#
#
# Processing URL 7: https://www.sciencedirect.com/science/article/pii/S0378378220307088
# ================================================================================
# Processing: https://www.sciencedirect.com/science/article/pii/S0378378220307088
# Fetching: https://www.sciencedirect.com/science/article/pii/S0378378220307088
# ⚠️ HTTP error for https://www.sciencedirect.com/science/article/pii/S0378378220307088: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S0378378220307088
#    -> Skipping content extraction for this URL.
# ⚠️ No text fetched for this URL. Creating empty diagram.
# ✅ Saved mermaid_7.md
#
#
# Processing URL 8: https://www.frontiersin.org/news/2025/09/01/rectangle-telescope-finding-habitable-planets
# ================================================================================
# Processing: https://www.frontiersin.org/news/2025/09/01/rectangle-telescope-finding-habitable-planets
# Fetching: https://www.frontiersin.org/news/2025/09/01/rectangle-telescope-finding-habitable-planets
# Text split into 7 chunks.
#   Extracting entities from chunk 1/7...
#   Extracting entities from chunk 2/7...
#   Extracting entities from chunk 3/7...
#   Extracting entities from chunk 4/7...
#   Extracting entities from chunk 5/7...
#   Extracting entities from chunk 6/7...
#   Extracting entities from chunk 7/7...
# Total raw entities: 149
# Dedup confidence from LLM: 0.98
# Deduplicated entities: 108
#   Extracting triples...
# Total triples: 27
# ✅ Saved mermaid_8.md
#
#
# Processing URL 9: https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7
# ================================================================================
# Processing: https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7
# Fetching: https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7
# ⚠️ HTTP error for https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7: 403 Client Error: Forbidden for url: https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7
#    -> Skipping content extraction for this URL.
# ⚠️ No text fetched for this URL. Creating empty diagram.
# ✅ Saved mermaid_9.md
#
#
# Processing URL 10: https://www.theguardian.com/global-development/2025/oct/13/astro-ambassadors-stargazers-himalayas-hanle-ladakh-india
# ================================================================================
# Processing: https://www.theguardian.com/global-development/2025/oct/13/astro-ambassadors-stargazers-himalayas-hanle-ladakh-india
# Fetching: https://www.theguardian.com/global-development/2025/oct/13/astro-ambassadors-stargazers-himalayas-hanle-ladakh-india
# Text split into 6 chunks.
#   Extracting entities from chunk 1/6...
#   Extracting entities from chunk 2/6...
#   Extracting entities from chunk 3/6...
#   Extracting entities from chunk 4/6...
#   Extracting entities from chunk 5/6...
#   Extracting entities from chunk 6/6...
# Total raw entities: 131
# Dedup confidence from LLM: 0.98
# Deduplicated entities: 102
#   Extracting triples...
# Total triples: 58
# ✅ Saved mermaid_10.md
#
#  All done. Saved tags.csv
#                                                 link                      tag  \
# 0  https://en.wikipedia.org/wiki/Sustainable_agri...  Sustainable agriculture
# 1  https://en.wikipedia.org/wiki/Sustainable_agri...                Wikipedia
# 2  https://en.wikipedia.org/wiki/Sustainable_agri...       shade-grown coffee
# 3  https://en.wikipedia.org/wiki/Sustainable_agri...              polyculture
# 4  https://en.wikipedia.org/wiki/Sustainable_agri...       natural ecosystems
#
#        tag_type
# 0       Concept
# 1  Organization
# 2       Process
# 3       Process
# 4       Concept

# %%
# !zip -r DSPy_Assignment_Krishna.zip mermaid_*.md tags.csv
# Out:
#   adding: mermaid_10.md (deflated 68%)
#   adding: mermaid_1.md (deflated 81%)
#   adding: mermaid_2.md (deflated 62%)
#   adding: mermaid_3.md (stored 0%)
#   adding: mermaid_4.md (stored 0%)
#   adding: mermaid_5.md (deflated 71%)
#   adding: mermaid_6.md (stored 0%)
#   adding: mermaid_7.md (stored 0%)
#   adding: mermaid_8.md (deflated 64%)
#   adding: mermaid_9.md (stored 0%)
#   adding: tags.csv (deflated 88%)

# %% [markdown]
# In this project, the extraction of the structured information of the web article with the help of DSPy and a LongCat OpenAI-compatible language model relies on an automated pipeline. The process starts with scraping of text based content of each of the URLs and breaking it into pieces that are easy to process. Each chunk is presented to the LLM, and the named entities are extracted and the semantic triples (source relation destination) are also produced. In order to provide consistency, the obtained results are verified, regularised, and added to the world list of mined elements.
#
# A list of deduplicated entities is then narrowed down to meaningful non-duplicated concepts by applying the deduplication logic of DSPy to all the chunks with its deduplication logic, after which all non-bafores are filtered out leaving only meaningful non-repetitive concepts. The triples are then filtered such that relationships between these ultimate deduplicated entities only are retained. The triples are cleaned automatically to produce Mermaid diagrams as follows: entities are the graph nodes of each node, and triples comprise a label connexion. In case there are no valid triples on a particular URL, then a fallback chain diagram is constructed, so that a valid Mermaid file is always created.
#
# At last, the tagged diagrams (mermaid_1.md to mermaid_10.md) and the tabular representation of all the entities (tags.csv) are saved and exported into a zip file to submit. This pipeline is fully automated and reproducible providing a way of transforming raw text into Knowledge graphs in a structured form.
