# %% [markdown]
# **Library installation and imports**

# %%
# !pip install --quiet dspy-ai beautifulsoup4 requests rapidfuzz python-dotenv
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 37.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 108.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 18.5 MB/s eta 0:00:00

# %%
# !pip install dspy-ai
# Out:
# Requirement already satisfied: dspy-ai in /usr/local/lib/python3.12/dist-packages (3.0.3)
# Requirement already satisfied: dspy>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from dspy-ai) (3.0.3)
# Requirement already satisfied: backoff>=2.2 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.2.1)
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (1.5.2)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (1.109.1)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2024.11.6)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (3.11.3)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (4.67.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.32.4)
# Requirement already satisfied: optuna>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (4.5.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.11.10)
# Requirement already satisfied: magicattr>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (0.1.6)
# Requirement already satisfied: litellm>=1.64.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (1.79.0)
# Requirement already satisfied: diskcache>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (5.6.3)
# Requirement already satisfied: json-repair>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (0.52.3)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (8.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (4.11.0)
# Requirement already satisfied: asyncer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (0.0.8)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (5.5.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (3.1.1)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (13.9.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (3.6.0)
# Requirement already satisfied: gepa==0.0.7 in /usr/local/lib/python3.12/dist-packages (from gepa[dspy]==0.0.7->dspy>=3.0.3->dspy-ai) (0.0.7)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.3->dspy-ai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.3->dspy-ai) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.3->dspy-ai) (4.15.0)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.13.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (8.3.0)
# Requirement already satisfied: fastuuid>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.14.0)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (4.25.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.1.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.22.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.0.3->dspy-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.0.3->dspy-ai) (0.11.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (1.17.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (2.0.44)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.3->dspy-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.3->dspy-ai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.3->dspy-ai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.3->dspy-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.3->dspy-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.3->dspy-ai) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy>=3.0.3->dspy-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy>=3.0.3->dspy-ai) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (1.3.10)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.27.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->dspy>=3.0.3->dspy-ai) (0.1.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (3.2.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.35.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.1.10)

# %%
import os
import re
import json
import time
import csv
import copy
from typing import List, Dict, Any
from pydantic import BaseModel, Field

import requests
from bs4 import BeautifulSoup
from rapidfuzz import fuzz


import dspy
from dspy.adapters import XMLAdapter

# %% [markdown]
# **API Key Setup and DSPy Model Configuration**

# %%
import os
from dotenv import load_dotenv
load_dotenv()
API_KEY = os.getenv("API_KEY")

# %%
key = "ak_1cI2XZ9tq9OS2a12Tw01Y6a61y24E"

# This creates the .env file automatically
with open(".env", "w") as f:
    f.write(f"API_KEY={key}")

print("✅ .env file created successfully!")
# Out:
# ✅ .env file created successfully!

# %%
# !pip install dspy-ai python-dotenv

from dotenv import load_dotenv
import os
import dspy
from dspy.adapters import XMLAdapter

load_dotenv()
API_KEY = os.getenv("API_KEY")

main_lm = dspy.LM(
    "openai/LongCat-Flash-Chat",
    api_key=API_KEY,
    api_base="https://api.longcat.chat/openai/v1"
)
dspy.settings.configure(lm=main_lm, adapter=XMLAdapter())

print("✅ DSPy model configured successfully.")
# Out:
# Requirement already satisfied: dspy-ai in /usr/local/lib/python3.12/dist-packages (3.0.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: dspy>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from dspy-ai) (3.0.3)
# Requirement already satisfied: backoff>=2.2 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.2.1)
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (1.5.2)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (1.109.1)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2024.11.6)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (3.11.3)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (4.67.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.32.4)
# Requirement already satisfied: optuna>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (4.5.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.11.10)
# Requirement already satisfied: magicattr>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (0.1.6)
# Requirement already satisfied: litellm>=1.64.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (1.79.0)
# Requirement already satisfied: diskcache>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (5.6.3)
# Requirement already satisfied: json-repair>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (0.52.3)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (8.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (4.11.0)
# Requirement already satisfied: asyncer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (0.0.8)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (5.5.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (3.1.1)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (13.9.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy>=3.0.3->dspy-ai) (3.6.0)
# Requirement already satisfied: gepa==0.0.7 in /usr/local/lib/python3.12/dist-packages (from gepa[dspy]==0.0.7->dspy>=3.0.3->dspy-ai) (0.0.7)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.3->dspy-ai) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.3->dspy-ai) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy>=3.0.3->dspy-ai) (4.15.0)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.13.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (8.3.0)
# Requirement already satisfied: fastuuid>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.14.0)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (4.25.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.22.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.0.3->dspy-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy>=3.0.3->dspy-ai) (0.11.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (1.17.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (2.0.44)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.3->dspy-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.3->dspy-ai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy>=3.0.3->dspy-ai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.3->dspy-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.3->dspy-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy>=3.0.3->dspy-ai) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy>=3.0.3->dspy-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy>=3.0.3->dspy-ai) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (1.3.10)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.27.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->dspy>=3.0.3->dspy-ai) (0.1.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy>=3.0.3->dspy-ai) (3.2.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (0.35.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy>=3.0.3->dspy-ai) (1.1.10)
# ✅ DSPy model configured successfully.

# %% [markdown]
# **Web Scraping + Text Chunking Helpers**

# %%
# Cell: Scraping + chunking helpers
import re, requests
from bs4 import BeautifulSoup

def fetch_text(url: str, timeout: int = 12) -> str:
    try:
        resp = requests.get(url, timeout=timeout, headers={"User-Agent":"Mozilla/5.0"})
        resp.raise_for_status()
    except Exception as e:
        print(f"[fetch_text] error for {url}: {e}")
        return ""
    soup = BeautifulSoup(resp.text, "html.parser")
    for tag in soup(["script","style","nav","footer","aside","header","form","noscript","svg"]):
        tag.decompose()
    article = soup.find("article")
    if article:
        text = article.get_text(separator="\n")
    else:
        ps = soup.find_all("p")
        text = "\n".join(p.get_text() for p in ps)
    text = re.sub(r'\n\s+\n', '\n\n', text)
    return text.strip()

def chunk_text(text: str, chunk_chars: int = 3500):
    paras = [p.strip() for p in text.split("\n") if p.strip()]
    chunks, cur = [], ""
    for p in paras:
        if len(cur) + len(p) + 1 > chunk_chars:
            chunks.append(cur.strip())
            cur = p + "\n"
        else:
            cur += p + "\n"
    if cur.strip(): chunks.append(cur.strip())
    return chunks

# %% [markdown]
# **Define DSPy Entity and Relation Extraction Signatures**

# %%
# Cell: DSPy signatures (EntityWithAttr, ExtractEntities, DeduplicateEntities, Relation, ExtractRelations)
from pydantic import BaseModel, Field
from typing import List

class EntityWithAttr(BaseModel):
    entity: str = Field(..., description="the named entity")
    attr_type: str = Field(..., description="semantic type")

class ExtractEntities(dspy.Signature):
    paragraph: str = dspy.InputField(desc="input paragraph")
    entities: List[EntityWithAttr] = dspy.OutputField(desc="list of entities")

extractor = dspy.Predict(ExtractEntities)

class DeduplicateEntities(dspy.Signature):
    items: List[EntityWithAttr] = dspy.InputField(desc="batch of entities")
    deduplicated: List[EntityWithAttr] = dspy.OutputField(desc="deduped list")
    confidence: float = dspy.OutputField(desc="0-1 confidence")

dedup_predictor = dspy.ChainOfThought(DeduplicateEntities)

class Relation(BaseModel):
    subj: str = Field(...); pred: str = Field(...); obj: str = Field(...)

class ExtractRelations(dspy.Signature):
    paragraph: str = dspy.InputField(desc="original paragraph")
    entities: List[str] = dspy.InputField(desc="unique entity strings")
    relations: List[Relation] = dspy.OutputField(desc="triples")

rel_predictor = dspy.ChainOfThought(ExtractRelations)

# %% [markdown]
# **Deduplication Helpers**

# %%
# Cell: dedupe helpers + fallback (uses dedup_predictor; fallback local dedupe using rapidfuzz)
from rapidfuzz import fuzz
import time

def _fallback_local_dedupe(batch, threshold=88):
    norm_map = {}
    for e in batch:
        key = re.sub(r'[^a-z0-9\s\-\/%]', '', e.entity.lower()).strip()
        found = None
        for k in norm_map:
            if fuzz.token_sort_ratio(k, key) >= threshold:
                found = k; break
        if found:
            existing = norm_map[found]
            if len(e.entity) > len(existing.entity):
                norm_map[found] = e
        else:
            norm_map[key] = e
    return list(norm_map.values())

def deduplicate_with_lm(items, batch_size=10, target_confidence=0.9):
    if not items: return []
    def _process_batch(batch):
        while True:
            pred = dedup_predictor(items=batch)
            conf = getattr(pred, "confidence", None)
            deduped = getattr(pred, "deduplicated", None)
            if conf is None:
                return _fallback_local_dedupe(batch)
            if conf >= target_confidence:
                return deduped
            time.sleep(0.5)
    results=[]
    for i in range(0, len(items), batch_size):
        batch = items[i:i+batch_size]
        results.extend(_process_batch(batch))
    return results

# %% [markdown]
# **Relation Extraction + Mermaid Diagram Serializer**

# %%
# Cell: relation wrapper + mermaid serializer
def extract_relations_for_paragraph(paragraph, entities):
    try:
        out = rel_predictor(paragraph=paragraph, entities=entities)
        return getattr(out, "relations", []) or []
    except Exception as e:
        print("Relation predictor error:", e)
        return []

def triples_to_mermaid(triples, entity_list, max_label_len=40):
    entity_set = {e.strip().lower() for e in entity_list}
    lines = ["flowchart LR"]
    def make_id(s): return re.sub(r'[^0-9a-zA-Z]', '_', s.strip()) or "node"
    for t in triples:
        subj_norm = t.subj.strip(); obj_norm = t.obj.strip()
        if subj_norm.lower() not in entity_set and obj_norm.lower() not in entity_set:
            continue
        lbl = (t.pred or "").strip()
        if len(lbl) > max_label_len: lbl = lbl[:max_label_len-3] + "..."
        src_id = _make_id(subj_norm); dst_id = _make_id(obj_norm)
        src = subj_norm.replace('"', '\\"'); dst = obj_norm.replace('"', '\\"'); lbl = lbl.replace('"','\\"')
        lines.append(f'  {src_id}["{src}"] -->|"{lbl}"| {dst_id}["{dst}"]')
    return "\n".join(lines)

# %% [markdown]
# **Define URLs for Processing**

# %%
# Cell: urls added
urls = [
    "https://en.wikipedia.org/wiki/Sustainable_agriculture",


    "https://www.nature.com/articles/d41586-025-03353-5",
    "https://www.sciencedirect.com/science/article/pii/S1043661820315152",

    "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/",

    "https://www.fao.org/3/y4671e/y4671e06.htm",

     "https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria",

     "https://www.sciencedirect.com/science/article/pii/S0378378220307088",

     "https://www.frontiersin.org/news/2025/09/01/rectangle-telescope-finding-habitable-planets",

     "https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7",

     "https://www.theguardian.com/global-development/2025/oct/13/astro-ambassadors-stargazers-himalayas-hanle-ladakh-india"
    ]

# %% [markdown]
# **Run Extraction, Deduplication abd Save Outputs**

# %%
# Cell: run extraction -> dedupe -> relation for all URLs and collect outputs
all_raw_entities = []
all_relations = []

for url in urls:
    print("Processing:", url)
    txt = fetch_text(url)
    if not txt:
        print("  (no text extracted)")
        continue
    chunks = chunk_text(txt, chunk_chars=3500)
    url_entities = []
    for chunk in chunks:
        try:
            out = extractor(paragraph=chunk)
            extracted = getattr(out, "entities", []) or []
            for e in extracted:
                ent = EntityWithAttr(entity=e.entity.strip(), attr_type=e.attr_type.strip())
                url_entities.append(ent)
        except Exception as e:
            print("  extractor error:", e)
        time.sleep(0.2)
    # unique per url
    seen=set(); uniq=[]
    for e in url_entities:
        key=(e.entity.strip().lower(), e.attr_type.strip().lower())
        if key not in seen:
            seen.add(key); uniq.append(e)
    print(f"  extracted {len(url_entities)} items, {len(uniq)} unique (pre-dedupe)")
    deduped = deduplicate_with_lm(uniq, batch_size=10, target_confidence=0.9)
    print(f"  deduped -> {len(deduped)}")
    for e in deduped:
        all_raw_entities.append({"source":url, "entity":e.entity, "attr_type":e.attr_type})
    entity_strings = [e.entity for e in deduped]
    rels = extract_relations_for_paragraph(txt, entity_strings)
    for r in rels:
        all_relations.append({"source":url, "subj":r.subj, "pred":r.pred, "obj":r.obj})
    time.sleep(0.5)

print("Done extraction.")
print("Total entities collected:", len(all_raw_entities))
print("Total relations collected:", len(all_relations))
# Out:
# Processing: https://en.wikipedia.org/wiki/Sustainable_agriculture
#   extracted 818 items, 776 unique (pre-dedupe)
#   deduped -> 765
# Processing: https://www.nature.com/articles/d41586-025-03353-5
#   extracted 30 items, 30 unique (pre-dedupe)
#   deduped -> 29
# Processing: https://www.sciencedirect.com/science/article/pii/S1043661820315152
# [fetch_text] error for https://www.sciencedirect.com/science/article/pii/S1043661820315152: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S1043661820315152
#   (no text extracted)
# Processing: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/
#   extracted 721 items, 597 unique (pre-dedupe)
#   deduped -> 587
# Processing: https://www.fao.org/3/y4671e/y4671e06.htm
#   extracted 201 items, 178 unique (pre-dedupe)
#   deduped -> 175
# Processing: https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria
#   extracted 75 items, 72 unique (pre-dedupe)
#   deduped -> 72
# Processing: https://www.sciencedirect.com/science/article/pii/S0378378220307088
# [fetch_text] error for https://www.sciencedirect.com/science/article/pii/S0378378220307088: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S0378378220307088
#   (no text extracted)
# Processing: https://www.frontiersin.org/news/2025/09/01/rectangle-telescope-finding-habitable-planets
#   extracted 7 items, 7 unique (pre-dedupe)
#   deduped -> 7
# Processing: https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7
#   extracted 43 items, 43 unique (pre-dedupe)
#   deduped -> 41
# Processing: https://www.theguardian.com/global-development/2025/oct/13/astro-ambassadors-stargazers-himalayas-hanle-ladakh-india
#   extracted 77 items, 70 unique (pre-dedupe)
#   deduped -> 70
# Done extraction.
# Total entities collected: 1746
# Total relations collected: 466

# %% [markdown]
# **Save and Preview Results**

# %%
import json
import pandas as pd

# --- Save entities ---
with open("entities_results.json", "w") as f:
    json.dump(all_raw_entities, f, indent=4)
print("✅ Entities saved to 'entities_results.json'")

# --- Save relations ---
with open("relations_results.json", "w") as f:
    json.dump(all_relations, f, indent=4)
print("✅ Relations saved to 'relations_results.json'")

# --- Optional: Preview in a table ---
entities_df = pd.DataFrame(all_raw_entities)
relations_df = pd.DataFrame(all_relations)

print("\n🔹 Sample Entities:")
display(entities_df.head(10))

print("\n🔹 Sample Relations:")
display(relations_df.head(10))
# Out:
# ✅ Entities saved to 'entities_results.json'
# ✅ Relations saved to 'relations_results.json'
#
# 🔹 Sample Entities:
#                                               source  \
# 0  https://en.wikipedia.org/wiki/Sustainable_agri...
# 1  https://en.wikipedia.org/wiki/Sustainable_agri...
# 2  https://en.wikipedia.org/wiki/Sustainable_agri...
# 3  https://en.wikipedia.org/wiki/Sustainable_agri...
# 4  https://en.wikipedia.org/wiki/Sustainable_agri...
# 5  https://en.wikipedia.org/wiki/Sustainable_agri...
# 6  https://en.wikipedia.org/wiki/Sustainable_agri...
# 7  https://en.wikipedia.org/wiki/Sustainable_agri...
# 8  https://en.wikipedia.org/wiki/Sustainable_agri...
# 9  https://en.wikipedia.org/wiki/Sustainable_agri...
#
#                         entity   attr_type
# 0      Sustainable agriculture     concept
# 1                      farming    activity
# 2                         food    resource
# 3                textile needs    resource
# 4           ecosystem services     concept
# 5     sustainable food systems     concept
# 6  flexible business processes     concept
# 7            farming practices    activity
# 8      environmental footprint     concept
# 9               climate change  phenomenon
# 🔹 Sample Relations:
#                                               source  \
# 0  https://en.wikipedia.org/wiki/Sustainable_agri...
# 1  https://en.wikipedia.org/wiki/Sustainable_agri...
# 2  https://en.wikipedia.org/wiki/Sustainable_agri...
# 3  https://en.wikipedia.org/wiki/Sustainable_agri...
# 4  https://en.wikipedia.org/wiki/Sustainable_agri...
# 5  https://en.wikipedia.org/wiki/Sustainable_agri...
# 6  https://en.wikipedia.org/wiki/Sustainable_agri...
# 7  https://en.wikipedia.org/wiki/Sustainable_agri...
# 8  https://en.wikipedia.org/wiki/Sustainable_agri...
# 9  https://en.wikipedia.org/wiki/Sustainable_agri...
#
#                                                 subj  \
# 0                            Sustainable agriculture
# 1                            Sustainable agriculture
# 2                            Sustainable agriculture
# 3                           sustainable food systems
# 4                                        Agriculture
# 5                            Sustainable agriculture
# 6                Elements of sustainable agriculture
# 7                            sustainable agriculture
# 8                                     dietary shifts
# 9  sustainability standards and certification sys...
#
#                                               pred  \
# 0                                               is
# 1                                          meeting
# 2                                         based on
# 3                             important to develop
# 4                                          causing
# 5                                      consists of
# 6                                         includes
# 7                                can be considered
# 8  intertwined way to reduce environmental impacts
# 9                                            exist
#
#                                                  obj
# 0                                   sustainable ways
# 1           society's present food and textile needs
# 2                                 ecosystem services
# 3  flexible business processes and farming practices
# 4  climate change, water scarcity, water pollutio...
# 5                       environment friendly methods
# 6  permaculture, agroforestry, mixed farming, mul...
# 7                                       Land sparing
# 8                                  sustainable diets
# 9  organic certification, Rainforest Alliance, Fa...
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('subj').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### ** Note on Number of Mermaid Diagrams**
#
# The assignment specifies creating 10 Mermaid diagrams (one per source document).
# However, after executing the data extraction and relation generation steps, only *8 unique sources* produced valid relation triples.
#
# Hence, *8 valid Mermaid diagrams* were generated (mermaid_1.md to mermaid_8.md).
# This accurately represents the data quality and the actual model output, ensuring transparency in reporting results.

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_0.groupby('subj').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Inspect columns & first rows
print(entities_df.columns)
entities_df.head(10)
# Out:
# Index(['source', 'entity', 'attr_type'], dtype='object')
#                                               source  \
# 0  https://en.wikipedia.org/wiki/Sustainable_agri...
# 1  https://en.wikipedia.org/wiki/Sustainable_agri...
# 2  https://en.wikipedia.org/wiki/Sustainable_agri...
# 3  https://en.wikipedia.org/wiki/Sustainable_agri...
# 4  https://en.wikipedia.org/wiki/Sustainable_agri...
# 5  https://en.wikipedia.org/wiki/Sustainable_agri...
# 6  https://en.wikipedia.org/wiki/Sustainable_agri...
# 7  https://en.wikipedia.org/wiki/Sustainable_agri...
# 8  https://en.wikipedia.org/wiki/Sustainable_agri...
# 9  https://en.wikipedia.org/wiki/Sustainable_agri...
#
#                         entity   attr_type
# 0      Sustainable agriculture     concept
# 1                      farming    activity
# 2                         food    resource
# 3                textile needs    resource
# 4           ecosystem services     concept
# 5     sustainable food systems     concept
# 6  flexible business processes     concept
# 7            farming practices    activity
# 8      environmental footprint     concept
# 9               climate change  phenomenon

# %%
# Build cleaned DataFrame for export
tags_df = entities_df.rename(columns={"source":"link", "entity":"tag", "attr_type":"tag_type"})[["link","tag","tag_type"]].copy()

# Normalize: strip, collapse spaces, and trim tag size (optional)
tags_df["tag"] = tags_df["tag"].astype(str).str.strip().str.replace(r"\s+"," ", regex=True)
tags_df["tag_type"] = tags_df["tag_type"].astype(str).str.strip().str.capitalize()  # e.g., "concept"

# %%
# Remove duplicate tag entries for same link
before = len(tags_df)
tags_df = tags_df.drop_duplicates(subset=["link","tag"])
after = len(tags_df)
print(f"Removed {before-after} duplicates. Final rows: {after}")
# Out:
# Removed 158 duplicates. Final rows: 1588

# %%
# Check for empty values
print("Missing links:", tags_df['link'].isna().sum())
print("Missing tags:", tags_df['tag'].isna().sum())

# Sample counts by tag_type
print(tags_df['tag_type'].value_counts())
# Out:
# Missing links: 0
# Missing tags: 0
# tag_type
# Concept                  133
# Person                    57
# Organization              56
# Agricultural practice     37
# Citation                  35
#                         ...
# Medical specialty          1
# Physiological process      1
# Field of study             1
# Celestial body             1
# Medical_treatment          1
# Name: count, Length: 389, dtype: int64

# %%
tags_df.to_csv("tags.csv", index=False)
print("✅ tags.csv saved.")
# Out:
# ✅ tags.csv saved.

# %%
relations_df.head(10)
# Out:
#                                               source  \
# 0  https://en.wikipedia.org/wiki/Sustainable_agri...
# 1  https://en.wikipedia.org/wiki/Sustainable_agri...
# 2  https://en.wikipedia.org/wiki/Sustainable_agri...
# 3  https://en.wikipedia.org/wiki/Sustainable_agri...
# 4  https://en.wikipedia.org/wiki/Sustainable_agri...
# 5  https://en.wikipedia.org/wiki/Sustainable_agri...
# 6  https://en.wikipedia.org/wiki/Sustainable_agri...
# 7  https://en.wikipedia.org/wiki/Sustainable_agri...
# 8  https://en.wikipedia.org/wiki/Sustainable_agri...
# 9  https://en.wikipedia.org/wiki/Sustainable_agri...
#
#                                                 subj  \
# 0                            Sustainable agriculture
# 1                            Sustainable agriculture
# 2                            Sustainable agriculture
# 3                           sustainable food systems
# 4                                        Agriculture
# 5                            Sustainable agriculture
# 6                Elements of sustainable agriculture
# 7                            sustainable agriculture
# 8                                     dietary shifts
# 9  sustainability standards and certification sys...
#
#                                               pred  \
# 0                                               is
# 1                                          meeting
# 2                                         based on
# 3                             important to develop
# 4                                          causing
# 5                                      consists of
# 6                                         includes
# 7                                can be considered
# 8  intertwined way to reduce environmental impacts
# 9                                            exist
#
#                                                  obj
# 0                                   sustainable ways
# 1           society's present food and textile needs
# 2                                 ecosystem services
# 3  flexible business processes and farming practices
# 4  climate change, water scarcity, water pollutio...
# 5                       environment friendly methods
# 6  permaculture, agroforestry, mixed farming, mul...
# 7                                       Land sparing
# 8                                  sustainable diets
# 9  organic certification, Rainforest Alliance, Fa...

# %%
import re

def _make_id(s):
    # Create safe node id for Mermaid (no spaces or special chars)
    s = re.sub(r'[^0-9a-zA-Z]', '_', s.strip())
    if not s:
        s = "node"
    return s

def triples_to_mermaid_from_rows(rows, max_label_len=40):
    """
    rows: iterable of dicts or DataFrame rows with keys subj/pred/obj
    returns mermaid markdown string (flowchart LR)
    """
    lines = ["mermaid", "flowchart LR"]
    # collect allowed entity set to filter stray relations
    allowed = set()
    for r in rows:
        allowed.add(str(r['subj']).strip())
        allowed.add(str(r['obj']).strip())
    for r in rows:
        subj = str(r['subj']).strip()
        obj = str(r['obj']).strip()
        pred = str(r['pred']).strip()
        if not subj or not obj:
            continue
        if subj not in allowed and obj not in allowed:
            continue
        lbl = pred
        if len(lbl) > max_label_len:
            lbl = lbl[:max_label_len-3] + "..."
        src_id = _make_id(subj)
        dst_id = _make_id(obj)
        # escape double quotes inside labels/nodes
        subj_esc = subj.replace('"','\\"')
        obj_esc = obj.replace('"','\\"')
        lbl_esc = lbl.replace('"','\\"')
        lines.append(f'  {src_id}["{subj_esc}"] -->|"{lbl_esc}"| {dst_id}["{obj_esc}"]')
    lines.append("")
    return "\n".join(lines)

# %%
# Group relations by source
groups = list(relations_df.groupby("source"))
print("Sources found:", len(groups))

for i, (src, df_grp) in enumerate(groups, start=1):
    rows = df_grp.to_dict(orient="records")
    mermaid_text = triples_to_mermaid_from_rows(rows, max_label_len=40)
    fname = f"mermaid_{i}.md"
    with open(fname, "w", encoding="utf-8") as f:
        f.write(mermaid_text)
    print(f"Saved {fname} for source: {src}  (relations: {len(rows)})")
# Out:
# Sources found: 8
# Saved mermaid_1.md for source: https://en.wikipedia.org/wiki/Sustainable_agriculture  (relations: 102)
# Saved mermaid_2.md for source: https://www.fao.org/3/y4671e/y4671e06.htm  (relations: 62)
# Saved mermaid_3.md for source: https://www.frontiersin.org/news/2025/09/01/rectangle-telescope-finding-habitable-planets  (relations: 7)
# Saved mermaid_4.md for source: https://www.medscape.com/viewarticle/second-dose-boosts-shingles-protection-adults-aged-65-years-2025a1000ro7  (relations: 43)
# Saved mermaid_5.md for source: https://www.medscape.com/viewarticle/time-reconsider-tramadol-chronic-pain-2025a1000ria  (relations: 69)
# Saved mermaid_6.md for source: https://www.nature.com/articles/d41586-025-03353-5  (relations: 22)
# Saved mermaid_7.md for source: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10457221/  (relations: 62)
# Saved mermaid_8.md for source: https://www.theguardian.com/global-development/2025/oct/13/astro-ambassadors-stargazers-himalayas-hanle-ladakh-india  (relations: 99)

# %%
# !sed -n '1,120p' mermaid_1.md  # shows first file content in Colab
# Out:
# mermaid
# flowchart LR
#   Sustainable_agriculture["Sustainable agriculture"] -->|"is"| sustainable_ways["sustainable ways"]
#   Sustainable_agriculture["Sustainable agriculture"] -->|"meeting"| society_s_present_food_and_textile_needs["society's present food and textile needs"]
#   Sustainable_agriculture["Sustainable agriculture"] -->|"based on"| ecosystem_services["ecosystem services"]
#   sustainable_food_systems["sustainable food systems"] -->|"important to develop"| flexible_business_processes_and_farming_practices["flexible business processes and farming practices"]
#   Agriculture["Agriculture"] -->|"causing"| climate_change__water_scarcity__water_pollution__land_degradation__deforestation["climate change, water scarcity, water pollution, land degradation, deforestation"]
#   Sustainable_agriculture["Sustainable agriculture"] -->|"consists of"| environment_friendly_methods["environment friendly methods"]
#   Elements_of_sustainable_agriculture["Elements of sustainable agriculture"] -->|"includes"| permaculture__agroforestry__mixed_farming__multiple_cropping__crop_rotation["permaculture, agroforestry, mixed farming, multiple cropping, crop rotation"]
#   sustainable_agriculture["sustainable agriculture"] -->|"can be considered"| Land_sparing["Land sparing"]
#   dietary_shifts["dietary shifts"] -->|"intertwined way to reduce environment..."| sustainable_diets["sustainable diets"]
#   sustainability_standards_and_certification_systems["sustainability standards and certification systems"] -->|"exist"| organic_certification__Rainforest_Alliance__Fair_Trade__UTZ_Certified__GlobalGAP__Bird_Friendly__Common_Code_for_the_Coffee_Community__4C_["organic certification, Rainforest Alliance, Fair Trade, UTZ Certified, GlobalGAP, Bird Friendly, Common Code for the Coffee Community (4C)"]
#   The_term__sustainable_agriculture_["The term 'sustainable agriculture'"] -->|"defined in"| 1977["1977"]
#   the_idea_of_having_a_sustainable_relationship_with_the_land["the idea of having a sustainable relationship with the land"] -->|"prevalent in"| indigenous_communities["indigenous communities"]
#   sustainability_field["sustainability field"] -->|"adoption of"| technology["technology"]
#   Sustainable_agricultural_systems["Sustainable agricultural systems"] -->|"important field for"| AI_research_and_development["AI research and development"]
#   AI["AI"] -->|"skills in"| resource_optimization__crop_health_monitoring__yield_prediction["resource optimization, crop health monitoring, yield prediction"]
#   farmers["farmers"] -->|"optimize water consumption"| AI_controlled_irrigation_systems["AI-controlled irrigation systems"]
#   farmers["farmers"] -->|"enhances soil fertility"| Artificial_intelligence__AI__mobile_soil_analysis["Artificial intelligence (AI) mobile soil analysis"]
#   sustainable_agriculture["sustainable agriculture"] -->|"optimizes land use"| Agrivoltaics["Agrivoltaics"]
#   Practices["Practices"] -->|"can cause long-term damage"| excessive_tilling__irrigation_without_adequate_drainage["excessive tilling, irrigation without adequate drainage"]
#   climate__soil__nutrients_and_water_resources["climate, soil, nutrients and water resources"] -->|"most amenable to human intervention"| water_and_soil_conservation["water and soil conservation"]
#   harvesting_crops["harvesting crops"] -->|"causes"| nutrient_depletion["nutrient depletion"]
#   Sustainable_agriculture["Sustainable agriculture"] -->|"minimizing use of"| non_renewable_resources["non-renewable resources"]
#   application_of_fertilizer_or_manure["application of fertilizer or manure"] -->|"can pollute nearby rivers and coastal..."| eutrophication["eutrophication"]
#   Phosphorus_fertilizers["Phosphorus fertilizers"] -->|"manufactured from"| rock_phosphate["rock phosphate"]
#   rock_phosphate["rock phosphate"] -->|"will occur within the next few hundre..."| peak_phosphorus["peak phosphorus"]
#   KCl["KCl"] -->|"sustainable option for replacing"| chloride_free_fertilizers["chloride-free fertilizers"]
#   Earth_s_ice_free_land_area["Earth's ice-free land area"] -->|"subject to human-induced degradation"| soil_erosion["soil erosion"]
#   Modification_of_agricultural_practices["Modification of agricultural practices"] -->|"recognized method of"| carbon_sequestration["carbon sequestration"]
#   Soil_management_techniques["Soil management techniques"] -->|"include"| no_till_farming__keyline_design__windbreaks["no-till farming, keyline design, windbreaks"]
#   food_prices["food prices"] -->|"closely linked to"| energy_prices["energy prices"]
#   energy_smart_agricultural_systems["energy-smart agricultural systems"] -->|"move towards"| renewable_energy["renewable energy"]
#   agricultural_water_irrigation["agricultural water irrigation"] -->|"closed system for"| solar_powered_irrigation["solar powered irrigation"]
#   people["people"] -->|"could avoid environmental cost of tra..."| local_products["local products"]
#   water_well_drilling_technology_and_submersible_pumps["water well drilling technology and submersible pumps"] -->|"developments in"| drip_irrigation__low_pressure_pivots["drip irrigation, low-pressure pivots"]
#   many_areas["many areas"] -->|"water used faster than replenished"| Ogallala_Aquifer["Ogallala Aquifer"]
#   Farmers["Farmers"] -->|"way to save water"| wool["wool"]
#   agricultural_communities["agricultural communities"] -->|"promising proposal for rural poverty ..."| sustainable_economic_growth["sustainable economic growth"]
#   Uganda["Uganda"] -->|"explored as solution"| Genetically_Modified_Organisms["Genetically Modified Organisms"]
#   Nepal["Nepal"] -->|"built to deal with high altitude and ..."| greenhouses["greenhouses"]
#   areas_with_limited_water_supply["areas with limited water supply"] -->|"can turn salt water into fresh water"| desalination_techniques["desalination techniques"]
#   United_States["United States"] -->|"number tripled from 1978-2007"| women_farm_operators["women farm operators"]
#   US["US"] -->|"became widespread"| growing_food_in_the_backyard["growing food in the backyard"]
#   environmental_problems["environmental problems"] -->|"not covered in traditional accounting..."| externalities["externalities"]
#   sustainable_land_management["sustainable land management"] -->|"seek to establish economic cost-benef..."| The_Economics_of_Ecosystems_and_Biodiversity_study__Economics_of_Land_Degradation_Initiative["The Economics of Ecosystems and Biodiversity study, Economics of Land Degradation Initiative"]
#   sustainability["sustainability"] -->|"include social, environmental, financ..."| Triple_bottom_line_frameworks["Triple bottom line frameworks"]
#   direct_food_assistance["direct food assistance"] -->|"four times more cost-effective"| investment_in_sustainable_agriculture["investment in sustainable agriculture"]
#   barriers_to_sustainable_agriculture["barriers to sustainable agriculture"] -->|"core pillars to sustainability"| social__environmental__economic_pillars["social, environmental, economic pillars"]
#   Social_barriers["Social barriers"] -->|"include"| cultural_shifts__collaboration__incentives__new_legislation["cultural shifts, collaboration, incentives, new legislation"]
#   Environmental_barriers["Environmental barriers"] -->|"examples of"| pesticides__climate_change["pesticides, climate change"]
#   economic_obstacles["economic obstacles"] -->|"include"| low_financial_return__lack_of_financial_incentives__negligible_capital_investments["low financial return, lack of financial incentives, negligible capital investments"]
#   sustainable_agriculture["sustainable agriculture"] -->|"promising method of encouraging"| local_farming__community_gardens["local farming, community gardens"]
#   definition_of_sustainability["definition of sustainability"] -->|"two different approaches"| ecocentric_approach__technocentric_approach["ecocentric approach, technocentric approach"]
#   sustainable_agriculture["sustainable agriculture"] -->|"two different lenses"| multifunctional_agriculture__ecosystem_services["multifunctional agriculture, ecosystem services"]
#   crops["crops"] -->|"increases resistance to diseases"| polyculture["polyculture"]
#   land_reuse["land reuse"] -->|"from legumes"| nitrogen_fixation["nitrogen fixation"]
#   legumes["legumes"] -->|"replenishes nitrogen"| crop_rotation["crop rotation"]
#   Egypt["Egypt"] -->|"demonstrated increased productivity"| integrated_wheat_fish_farming["integrated wheat-fish farming"]
#   United_Nations["United Nations"] -->|"priority for"| sustainable_intensification["sustainable intensification"]
#   year_round_production["year-round production"] -->|"potential advantages"| Vertical_farming["Vertical farming"]
#   water_shortage["water shortage"] -->|"researched extensively"| drought_resistant_crops["drought resistant crops"]
#   recycling_centers["recycling centers"] -->|"soil amendments"| compost["compost"]
#   soil["soil"] -->|"increase crop growth"| phosphate_solubilizing_microorganisms["phosphate-solubilizing microorganisms"]
#   soil["soil"] -->|"increase nutrient uptake"| mycorrhizae["mycorrhizae"]
#   soil_sterilization["soil sterilization"] -->|"alternative to chemicals"| Soil_steaming__Solarizing["Soil steaming, Solarizing"]
#   Brassicaceae_family["Brassicaceae family"] -->|"natural fumigants"| biofumigants["biofumigants"]
#   global_crop_production["global crop production"] -->|"could decrease carbon footprint"| croplands_relocation["croplands relocation"]
#   crop_rotation["crop rotation"] -->|"prevent soil erosion"| cover_crops["cover crops"]
#   biodiversity_conservation["biodiversity conservation"] -->|"landscape management strategies"| land_sparing__land_sharing__land_blending["land sparing, land sharing, land blending"]
#   integrated_farming_system["integrated farming system"] -->|"prohibiting synthetic pesticides, ant..."| organic_agriculture["organic agriculture"]
#   regenerate_ecosystem_services["regenerate ecosystem services"] -->|"includes organic methods"| ecological_farming["ecological farming"]
#   ecological_farm["ecological farm"] -->|"converts organic waste"| biodigestors["biodigestors"]
#   ecological_farm["ecological farm"] -->|"combines fish farming with agricultur..."| aquaculture_integration["aquaculture integration"]
#   ecological_farm["ecological farm"] -->|"improves soil fertility"| organic_fertilizers["organic fertilizers"]
#   non_chemical_techniques["non-chemical techniques"] -->|"efficient removal of pests"| Precision_Agriculture["Precision Agriculture"]
#   ecological_farming["ecological farming"] -->|"reduce soil erosion"| contour_farming__strip_cropping__terrace_cultivation["contour farming, strip cropping, terrace cultivation"]
#   Amazon["Amazon"] -->|"practiced in"| slash_and_burn__slash_and_char["slash-and-burn, slash-and-char"]
#   South_East_Asia["South-East Asia"] -->|"raised in"| rice_fish_systems["rice-fish systems"]
#   Altiplano_region["Altiplano region"] -->|"recently revived in"| Waru_Waru["Waru Waru"]
#   dry_areas["dry areas"] -->|"common practice in"| water_harvesting["water harvesting"]
#   Native_Americans["Native Americans"] -->|"incorporated by"| Intercropping["Intercropping"]
#   Anishinaabe_tribes["Anishinaabe tribes"] -->|"ideology of"| the_Honorable_Harvest["the Honorable Harvest"]
#   Native_Americans["Native Americans"] -->|"practiced by"| agroforestry["agroforestry"]
#   conservation_and_rehabilitation["conservation and rehabilitation"] -->|"focuses on topsoil regeneration"| Regenerative_agriculture["Regenerative agriculture"]
#   land_management["land management"] -->|"adopts arrangements observed in natur..."| Permaculture["Permaculture"]
#   sustainable_agriculture["sustainable agriculture"] -->|"limited evidence for"| Polyculture["Polyculture"]
#   polyculture_systems["polyculture systems"] -->|"approach to sustainability"| perennial_crop_varieties["perennial crop varieties"]
#   sustainability["sustainability"] -->|"use of available city space"| Urban_agriculture["Urban agriculture"]
#   higher_crop_yields["higher crop yields"] -->|"alternative to agriculture"| Hydroponics["Hydroponics"]
#   Certification_systems["Certification systems"] -->|"important to agriculture community an..."| organic_certification__Rainforest_Alliance__Fair_Trade__UTZ_Certified__GlobalGAP__Bird_Friendly__Common_Code_for_the_Coffee_Community__4C_["organic certification, Rainforest Alliance, Fair Trade, UTZ Certified, GlobalGAP, Bird Friendly, Common Code for the Coffee Community (4C)"]
#   USDA["USDA"] -->|"supported by nationalized standards"| organic_label["organic label"]
#   reduce_environmental_risks["reduce environmental risks"] -->|"topic in international policy"| sustainable_agriculture["sustainable agriculture"]
#   European_Union["European Union"] -->|"program for making agriculture more s..."| From_Farm_to_Fork["From Farm to Fork"]
#   New_Deal["New Deal"] -->|"provided payments to farmers"| Agriculture_Adjustment_Act_of_1933["Agriculture Adjustment Act of 1933"]
#   future_policies["future policies"] -->|"promotes decentralized agrarian gover..."| Green_New_Deal["Green New Deal"]
#   Chinese_government["Chinese government"] -->|"plan adopted by"| 50__meat_consumption_reduction["50% meat consumption reduction"]
#   National_Basic_Research_Program["National Basic Research Program"] -->|"funded by"| Science_and_Technology_Backyard["Science and Technology Backyard"]
#   India["India"] -->|"teaches sustainable farming"| Sowgood_foundation["Sowgood foundation"]
#   Israeli_Ministry_of_Agriculture["Israeli Ministry of Agriculture"] -->|"funding programs for"| sustainable_agriculture_policy["sustainable agriculture policy"]
#   Franklin_H__King["Franklin H. King"] -->|"discusses advantages of"| Farmers_of_Forty_Centuries["Farmers of Forty Centuries"]
#   International_Society_of_Horticultural_Science["International Society of Horticultural Science"] -->|"symposium on"| sustainability_in_horticulture["sustainability in horticulture"]
#   English_political_economist["English political economist"] -->|"concerned about future inability to f..."| Thomas_Malthus["Thomas Malthus"]
#   The_State_of_the_World_s_Biodiversity_for_Food_and_Agriculture___In_Brief["The State of the World's Biodiversity for Food and Agriculture − In Brief"] -->|"licensed under"| CC_BY_SA_IGO_3_0["CC BY-SA IGO 3.0"]

# %%
import zipfile

zip_name = "assignment_submission.zip"
files_to_include = ["tags.csv", "entities_results.json", "relations_results.json"]  # add if exist
# add mermaid files
for i in range(1, len(groups)+1):
    files_to_include.append(f"mermaid_{i}.md")

# create zip
with zipfile.ZipFile(zip_name, "w") as z:
    for f in files_to_include:
        try:
            z.write(f)
            print("Added", f)
        except FileNotFoundError:
            print("Missing (skipped):", f)
print("Created", zip_name)
# Download
from google.colab import files
files.download(zip_name)
# Out:
# Added tags.csv
# Added entities_results.json
# Added relations_results.json
# Added mermaid_1.md
# Added mermaid_2.md
# Added mermaid_3.md
# Added mermaid_4.md
# Added mermaid_5.md
# Added mermaid_6.md
# Added mermaid_7.md
# Added mermaid_8.md
# Created assignment_submission.zip

# %%
relations_df['source'].nunique()
# Out:
# 8

# %%
print("Entities sources:", entities_df['source'].nunique())
print("Relations sources:", relations_df['source'].nunique())
missing = set(entities_df['source']) - set(relations_df['source'])
print("Sources with entities but no relations:", len(missing))
missing
# Out:
# Entities sources: 8
# Relations sources: 8
# Sources with entities but no relations: 0
# set()
